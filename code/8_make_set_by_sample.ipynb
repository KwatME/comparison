# %%
# %load_ext autoreload
# %autoreload 2

# %%
import gsea
from __init__ import *

# %%
nu_fe_sa = pd.read_csv("../output/number_feature_sample.tsv", sep="\t", index_col=0)

se_fe_ = kwat.gmt.read(kwat.path.list("../input/set/"))

st_se_in = pd.read_csv("../output/statistic_set_information.tsv", sep="\t", index_col=0)

# %%
en_se_sa = gsea.run_single_sample_gsea(
    nu_fe_sa,
    {se: se_fe_[se] for se in st_se_in.index[st_se_in.loc[:, "Selected"]]},
    mi=None,
    ma=None,
    n_jo=SETTING["n_jo"],
    pa="../output/",
)

en_se_sa
# Out:
# Selected 31618 sets (0 <= size <= inf).
#                                                      S6        S4        S2  \
# Set
# HP_DOWN_SLOPING_SHOULDERS                      0.459979  0.348154  0.482848
# GOBP_MATURE_RIBOSOME_ASSEMBLY                  0.595192  0.613591  0.348000
# BIOCARTA_AMAN_PATHWAY                          0.334313  0.344183  0.577182
# SIMBULAN_PARP1_TARGETS_UP                      0.495786  0.407862  0.448739
# GARCIA_TARGETS_OF_FLI1_AND_DAX1_UP             0.490467  0.530759  0.452819
# ...                                                 ...       ...       ...
# GSE40273_EOS_KO_VS_WT_TREG_UP                  0.390890  0.418679  0.388683
# VERRECCHIA_RESPONSE_TO_TGFB1_C6                0.462686  0.727928  0.769977
# GOBP_CIRCADIAN_SLEEP_WAKE_CYCLE_NON_REM_SLEEP  0.473055  0.614543 -0.646350
# GSE7831_1H_VS_4H_CPG_STIM_PDC_DN               0.419177  0.377973  0.458831
# HP_COGWHEEL_RIGIDITY                           0.502667  0.520131  0.601835
#
#                                                      S1        S7        S8  \
# Set
# HP_DOWN_SLOPING_SHOULDERS                      0.407620  0.324737  0.457650
# GOBP_MATURE_RIBOSOME_ASSEMBLY                  0.604932  0.461163  0.487945
# BIOCARTA_AMAN_PATHWAY                          0.470902  0.357522  0.407107
# SIMBULAN_PARP1_TARGETS_UP                      0.398147  0.376759  0.468432
# GARCIA_TARGETS_OF_FLI1_AND_DAX1_UP             0.429116  0.384628  0.470141
# ...                                                 ...       ...       ...
# GSE40273_EOS_KO_VS_WT_TREG_UP                  0.493337  0.393395  0.430719
# VERRECCHIA_RESPONSE_TO_TGFB1_C6               -0.546415  0.607958  0.576866
# GOBP_CIRCADIAN_SLEEP_WAKE_CYCLE_NON_REM_SLEEP  0.418725  0.500258  0.548322
# GSE7831_1H_VS_4H_CPG_STIM_PDC_DN               0.458490  0.398628  0.378754
# HP_COGWHEEL_RIGIDITY                           0.531405  0.324787  0.576665
#
#                                                      S5        S3
# Set
# HP_DOWN_SLOPING_SHOULDERS                      0.466087  0.411802
# GOBP_MATURE_RIBOSOME_ASSEMBLY                  0.496872  0.464937
# BIOCARTA_AMAN_PATHWAY                          0.408760  0.435432
# SIMBULAN_PARP1_TARGETS_UP                      0.474660  0.424823
# GARCIA_TARGETS_OF_FLI1_AND_DAX1_UP             0.440180  0.501773
# ...                                                 ...       ...
# GSE40273_EOS_KO_VS_WT_TREG_UP                  0.407143  0.419501
# VERRECCHIA_RESPONSE_TO_TGFB1_C6                0.496300  0.567218
# GOBP_CIRCADIAN_SLEEP_WAKE_CYCLE_NON_REM_SLEEP  0.502657  0.804113
# GSE7831_1H_VS_4H_CPG_STIM_PDC_DN               0.397505  0.440979
# HP_COGWHEEL_RIGIDITY                           0.579239  0.407387
#
# [31618 rows x 8 columns]

# %%
en_se_sa.reindex(labels=SETTING["se_"])
# Out:
#                                                           S6        S4  \
# Set
# HP_APNEIC_EPISODES_PRECIPITATED_BY_ILLNESS_FATI... -0.455353  0.500738
# HP_FATIGUE                                          0.422913  0.373551
# HP_CHRONIC_FATIGUE                                  0.487405  0.566576
# CD4+ in Celiac Disease 1                            0.382123  0.373236
# CD4+ in Celiac Disease 2                            0.385902  0.374290
#
#                                                           S2        S1  \
# Set
# HP_APNEIC_EPISODES_PRECIPITATED_BY_ILLNESS_FATI...  0.436301  0.571583
# HP_FATIGUE                                          0.427722  0.458579
# HP_CHRONIC_FATIGUE                                  0.410946  0.474127
# CD4+ in Celiac Disease 1                            0.403548  0.319840
# CD4+ in Celiac Disease 2                            0.427192  0.368259
#
#                                                           S7        S8  \
# Set
# HP_APNEIC_EPISODES_PRECIPITATED_BY_ILLNESS_FATI...  0.476276  0.545726
# HP_FATIGUE                                          0.391484  0.401982
# HP_CHRONIC_FATIGUE                                  0.384830  0.589264
# CD4+ in Celiac Disease 1                            0.403697  0.388311
# CD4+ in Celiac Disease 2                            0.363928  0.398102
#
#                                                           S5        S3
# Set
# HP_APNEIC_EPISODES_PRECIPITATED_BY_ILLNESS_FATI...  0.761130  0.460496
# HP_FATIGUE                                          0.402481  0.366011
# HP_CHRONIC_FATIGUE                                  0.467482  0.295053
# CD4+ in Celiac Disease 1                            0.418364  0.389755
# CD4+ in Celiac Disease 2                            0.414075  0.409005
