# %%
# %load_ext autoreload
# %autoreload 2

# %%
import gsea
from __init__ import *

# %%
bi_co_sa = pd.read_csv("../output/01_comparison_sample.tsv", sep="\t", index_col=0)

se_fe_ = kwat.gmt.read(kwat.path.list("../input/set/"))

st_se_in = pd.read_csv("../output/statistic_set_information.tsv", sep="\t", index_col=0)

# %%
for co in bi_co_sa.index:

    pa = "{}/{}".format(kwat.path.clean(co), SETTING["sc"])

    sc_ = pd.read_csv(
        "../output/compare_feature/{}/statistic.tsv".format(pa),
        sep="\t",
        index_col=0,
    ).loc[:, "Score"]

    pa = "../output/gsea/{}/".format(pa)

    kwat.path.make(pa)

    gsea.run_prerank_gsea(
        sc_,
        {se: se_fe_[se] for se in st_se_in.index[st_se_in.loc[:, "Selected"]]},
        mi=None,
        ma=None,
        n_jo=SETTING["n_jo"],
        n_pe=SETTING["n_sh"],
        pa=pa,
    )

    for se in SETTING["se_"]:

        break

        gsea._score_1_1(
            sc_,
            se_fe_[se],
            title="{}<br>{}".format(co, se),
            pa=pa,
        )
# Out:
# CFS => cfs
# Made ../output/gsea/
# Made ../output/gsea/cfs/
# Made ../output/gsea/cfs/get_ic/
# Selected 31618 sets (0 <= size <= inf).
# Permuting sets to compute p-values...
#   1/10
#   2/10
#   3/10
#   4/10
#   5/10
#   6/10
#   7/10
#   8/10
#   9/10
#   10/10
# CFS,TA vs CFS,CD4 => cfs_ta_vs_cfs_cd4
# Made ../output/gsea/cfs_ta_vs_cfs_cd4/
# Made ../output/gsea/cfs_ta_vs_cfs_cd4/get_ic/
# Selected 31618 sets (0 <= size <= inf).
# Permuting sets to compute p-values...
#   1/10
#   2/10
#   3/10
#   4/10
#   5/10
#   6/10
#   7/10
#   8/10
#   9/10
#   10/10
