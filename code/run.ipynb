# %%
# %load_ext autoreload
# %autoreload 2

# %%
from __init__ import *

# %%
nb_ = sorted(
    [na for na in os.listdir() if re.search(r"^\d+_.*\.ipynb$", na)],
    key=lambda na: int(na.split(sep="_", maxsplit=1)[0]),
)

nb_
# Out:
# ['1_process_feature_by_sample.ipynb',
#  '2_make_comparison_by_sample.ipynb',
#  '3_compare_feature.ipynb',
#  '4_get_extreme.ipynb',
#  '5_compare_feature_differences.ipynb',
#  '6_make_set_by_information.ipynb',
#  '7_run_prerank_gsea.ipynb',
#  '8_make_set_by_sample.ipynb',
#  '9_compare_set.ipynb',
#  '10_expand_set.ipynb',
#  '11_summarize.ipynb']

# %%
for nb in nb_:

    kwat.shell.run(
        "jupyter nbconvert --execute --ExecutePreprocessor.timeout=-1 --inplace {}".format(
            nb
        )
    )
# Out:
# jupyter nbconvert --execute --ExecutePreprocessor.timeout=-1 --inplace 1_process_feature_by_sample.ipynb
# jupyter nbconvert --execute --ExecutePreprocessor.timeout=-1 --inplace 2_make_comparison_by_sample.ipynb
# jupyter nbconvert --execute --ExecutePreprocessor.timeout=-1 --inplace 3_compare_feature.ipynb
# jupyter nbconvert --execute --ExecutePreprocessor.timeout=-1 --inplace 4_get_extreme.ipynb
# jupyter nbconvert --execute --ExecutePreprocessor.timeout=-1 --inplace 5_compare_feature_differences.ipynb
# jupyter nbconvert --execute --ExecutePreprocessor.timeout=-1 --inplace 6_make_set_by_information.ipynb
# jupyter nbconvert --execute --ExecutePreprocessor.timeout=-1 --inplace 7_run_prerank_gsea.ipynb
# jupyter nbconvert --execute --ExecutePreprocessor.timeout=-1 --inplace 8_make_set_by_sample.ipynb
# jupyter nbconvert --execute --ExecutePreprocessor.timeout=-1 --inplace 9_compare_set.ipynb
