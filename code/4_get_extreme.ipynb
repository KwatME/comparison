# %%
# %load_ext autoreload
# %autoreload 2

# %%
from __init__ import *

# %%
bi_co_sa = pd.read_csv("{}01_comparison_sample.tsv".format(PAO), sep="\t", index_col=0)

# %%
for co in bi_co_sa.index:

    pa = "{}/{}".format(kwat.path.clean(co), SETTING["sc"])

    sc_ = pd.read_csv(
        "{}compare_feature/{}/statistic.tsv".format(PAO, pa),
        sep="\t",
        index_col=0,
    ).loc[:, "Score"]

    pae = "{}extreme/{}/".format(PAO, pa)

    kwat.path.make(pae)

    for di, na in zip(["<", ">"], ["low", "high"]):

        kwat.series.get_extreme(
            sc_,
            di,
            "{}{}".format(
                pae,
                na,
            ),
            st=2,
        )
